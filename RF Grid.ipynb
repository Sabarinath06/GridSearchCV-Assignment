# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset=pd.read_csv("insurance_pre.csv")
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True)
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
indep=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
dep=dataset[['charges']]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(indep,dep,test_size=1/3,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.fit_transform(X_test)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
param_grid={'criterion':['squared_error', 'absolute_error', 'friedman_mse', 'poisson'], 'max_features': ['auto','sqrt','log2'],'n_estimators':[10,100]}
grid=GridSearchCV(RandomForestRegressor(), param_grid, refit=True, verbose=3,n_jobs=-1)
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# C:\Users\SABARINATH\ANACONDA\lib\site-packages\sklearn\model_selection\_search.py:909: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self.best_estimator_.fit(X, y, **fit_params)
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute_error',
#                                        'friedman_mse', 'poisson'],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'n_estimators': [10, 100]},
#              verbose=3)

# %%
re=grid.cv_results_
print("The R_score value for best parameter{}:".format(grid.best_params_))
# Out:
# The R_score value for best parameter{'criterion': 'poisson', 'max_features': 'log2', 'n_estimators': 100}:

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.224074      0.007259         0.002107        0.001720
# 1        1.129594      0.035434         0.045787        0.006112
# 2        0.098257      0.006364         0.009375        0.007655
# 3        0.865710      0.023135         0.048795        0.007710
# 4        0.098198      0.006064         0.006228        0.007636
# 5        0.870902      0.022742         0.042964        0.007016
# 6        0.344258      0.013357         0.008577        0.000473
# 7        3.493936      0.070769         0.043655        0.004539
# 8        0.213662      0.008258         0.004896        0.004297
# 9        2.116101      0.028408         0.043407        0.006002
# 10       0.226386      0.006311         0.010805        0.007836
# 11       2.153079      0.043415         0.045708        0.006062
# 12       0.123657      0.004031         0.000477        0.000586
# 13       1.089859      0.034165         0.039945        0.006566
# 14       0.099851      0.005490         0.013191        0.001793
# 15       0.881390      0.018190         0.043715        0.006890
# 16       0.093738      0.001845         0.011569        0.007277
# 17       0.876822      0.019512         0.040497        0.007383
# 18       0.184812      0.046501         0.009639        0.007885
# 19       1.233377      0.021942         0.037571        0.007699
# 20       0.104543      0.007542         0.008730        0.006416
# 21       0.953451      0.017729         0.038763        0.006043
# 22       0.099938      0.003683         0.013161        0.007875
# 23       0.845721      0.021311         0.033033        0.007136
#
#    param_criterion param_max_features param_n_estimators  \
# 0    squared_error               auto                 10
# 1    squared_error               auto                100
# 2    squared_error               sqrt                 10
# 3    squared_error               sqrt                100
# 4    squared_error               log2                 10
# 5    squared_error               log2                100
# 6   absolute_error               auto                 10
# 7   absolute_error               auto                100
# 8   absolute_error               sqrt                 10
# 9   absolute_error               sqrt                100
# 10  absolute_error               log2                 10
# 11  absolute_error               log2                100
# 12    friedman_mse               auto                 10
# 13    friedman_mse               auto                100
# 14    friedman_mse               sqrt                 10
# 15    friedman_mse               sqrt                100
# 16    friedman_mse               log2                 10
# 17    friedman_mse               log2                100
# 18         poisson               auto                 10
# 19         poisson               auto                100
# 20         poisson               sqrt                 10
# 21         poisson               sqrt                100
# 22         poisson               log2                 10
# 23         poisson               log2                100
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.791678
# 1   {'criterion': 'squared_error', 'max_features':...           0.800748
# 2   {'criterion': 'squared_error', 'max_features':...           0.808964
# 3   {'criterion': 'squared_error', 'max_features':...           0.809938
# 4   {'criterion': 'squared_error', 'max_features':...           0.780498
# 5   {'criterion': 'squared_error', 'max_features':...           0.805004
# 6   {'criterion': 'absolute_error', 'max_features'...           0.773438
# 7   {'criterion': 'absolute_error', 'max_features'...           0.788123
# 8   {'criterion': 'absolute_error', 'max_features'...           0.802793
# 9   {'criterion': 'absolute_error', 'max_features'...           0.797510
# 10  {'criterion': 'absolute_error', 'max_features'...           0.774534
# 11  {'criterion': 'absolute_error', 'max_features'...           0.801930
# 12  {'criterion': 'friedman_mse', 'max_features': ...           0